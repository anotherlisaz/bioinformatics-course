# %% [markdown]
# # Домашнее задание 7

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Нашли 3 последовательности S-белка SARS-CoV-2 в NCBI. Оказалось нетривиальной задачей, так как нужная последовательность объединена в одном файле со многими белок-кодирующими последовательностями. Рассмотрели эти 3:

# %% [markdown]
# ![Screenshot 2025-04-14 at 19.17.22.png](attachment:6be71c41-3c52-438d-8293-b76e65a11652.png)

# %% [markdown]
# ![Screenshot 2025-04-14 at 19.17.29.png](attachment:3a2fddb9-ac6f-4326-bed6-ef97996599f4.png)![Screenshot 2025-04-14 at 19.26.31.png](attachment:af2806c1-ad71-498a-b07e-37b9aa6904a5.png)

# %% [markdown]
# ![Screenshot 2025-04-14 at 19.26.31.png](attachment:e2706d76-a421-462a-ada8-8cd8c9eedd80.png)

# %% [markdown]
# Открыли формат Graphics, нашли S-белок, нашли его координаты, получили fasta файл. В текстовом редакторе объединила вс последовательногсти в один файл.

# %% [markdown]
# ![Screenshot 2025-04-14 at 19.03.52.png](attachment:0075aaa7-697c-4c55-ab36-c1cbf5b471f9.png)

# %% [markdown]
# ![Screenshot 2025-04-14 at 19.04.15.png](attachment:75c0ae9c-b13e-4f31-9ff5-3709af38615f.png)

# %% [markdown]
# Добавили к ним последовательность 10825, первую из файла с семинара.

# %% [markdown]
# Произвели выравнивание. Построили для последовательностей филогенетическое дерево.

# %% [markdown]
# ![Screenshot 2025-04-14 at 19.22.55.png](attachment:988eba75-e19f-4a99-8ba1-ce536faedc8d.png)

# %% [markdown]
# Вывод: найденные последовательности оказались близкими, а последовательность с семинара совсем далекой, возможно, так получилось, потому что добавленная последовательность получена при других условиях и у другого образца.

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Нашли в базе данных ортологов 5 последовательностей LCT-лактазы и построили для них филогенетическое дерево.

# %% [markdown]
# Наши ортологи: Homo sapiens (human), Rattus norvegicus (Norway rat), Mus musculus (house mouse), Macaca mulatta (Rhesus monkey), Bos taurus (domestic cattle).

# %% [markdown]
# ![Screenshot 2025-04-14 at 22.43.29.png](attachment:4442e550-6ab2-4257-91ce-5d538342db77.png)

# %% [markdown]
# Вывод: выравнивание было жутко долгое, зато полученный результат в виде дерева отвечает всем ожиданиям и логичным предположениям о родственности и эволюционной близости наших организмов.
