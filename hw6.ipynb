# %% [markdown]
# # Домашнее задание 6

# %% [markdown]
# ### Нашла в NCBI геномы двух организмов
# Искала геномы тут - https://www.ncbi.nlm.nih.gov/datasets/genome/

# %% [markdown]
# Danaus plexippus (monarch butterfly) (https://www.ncbi.nlm.nih.gov/datasets/genome/GCF_018135715.1/)

# %% [markdown]
# Rhinolophus ferrumequinum (greater horseshoe bat) (https://www.ncbi.nlm.nih.gov/datasets/genome/GCF_004115265.2/)

# %% [markdown]
# ### Скачала белковые последовательности этих геномов на сервер.
# Установила себе в окружение hmmer ПО NCBI для скачивания геномов

# %% [markdown]
# Команда для скачивания:
#
#     datasets download genome accession <id генома вашего любимого организма> --include protein

# %% [markdown]
# ### Нашла HMM для белкового домена

# %% [markdown]
# Выбрала DNA polymerase family A

# %% [markdown]
# https://www.ebi.ac.uk/interpro/entry/pfam/PF00476/logo/

# %% [markdown]
# ### Используя HMMER нашла в этих геномах белки, содержащие выбранный домен
#
# Записала выдачу HMMER в формате .txt в файлы. Запушила файлы на гитхаб.

# %% [markdown]
# Для первого организма:

# %% [markdown]
# ![Screenshot 2025-04-06 at 18.46.03.png](attachment:20040cee-9a73-4b63-8450-e666a98194b2.png)

# %% [markdown]
# ![Screenshot 2025-04-06 at 18.46.17.png](attachment:15cd1737-7f5c-4e17-9090-1551fef59dd4.png)

# %% [markdown]
# Для второго организма:

# %% [markdown]
# ![Screenshot 2025-04-06 at 18.52.42.png](attachment:0e285183-f871-4111-8d45-08f1ffded92e.png)

# %% [markdown]
# ![Screenshot 2025-04-06 at 18.53.01.png](attachment:71930f06-37d6-4744-91c8-6e51412e3466.png)

# %% [markdown]
# Построили их множественное выравнивание с помощью Clustal Omega.

# %% [markdown]
# ![Screenshot 2025-04-06 at 19.01.58.png](attachment:c392d73a-feb9-4fbc-b418-a776fa84c652.png)

# %% [markdown]
# Мотив найден, файл прикреплен, студент устал
